# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pandas as pd
from sklearn import preprocessing, svm
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x = np.array([1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021])
y = np.array([9.8, 10.2, 10.2, 10.6, 13.3, 15.1, 17.7, 20.6, 17.7, 16.8, 17, 17.2, 17.3, 17.8, 17.4, 17.2, 17.3, 16.9, 15.3, 13.6, 13.1, 13.4, 13.7, 13.9, 14.4, 14.1, 14.1, 14, 15.1, 16.4, 17.5, 17.7, 18.1, 19.2, 22, 24.1, 23.9, 23.7, 26.2, 26.7, 26.8, 26.9, 26.9, 27.4, 28.3, 28.9, 29.2, 29.8, 30, 30.4, 30.6, 31.1, 31.6, 32.7, 33.3, 34.9, 37, 38.8, 40.7, 41.7, 44.3, 48.6, 54.3, 56.8, 61.2, 65.2, 73.1, 83.3, 91.6, 97.5, 99.9, 104.5, 108, 109.7, 113.8, 118.5, 124.1, 130.4, 136.2, 140.9, 144.4, 148, 152.5, 157.3, 160.8, 163.2, 166.7, 172.4, 177.5, 180.7, 183.9, 189.4, 196.4, 203.5, 208.3, 218.8, 215.7, 218.3, 225.7, 229.8, 233.9, 238.3, 238.6, 240.6, 244.9, 251.9, 256.1, 260.3, 269.2])

# %%
plt.plot(x, y)
plt.xlabel('Year')
plt.ylabel('CPI')
plt.title("Historical Data - 1913-2021")
plt.show()

# %%
linear_years = [1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
linear_cpi = [83.3, 91.6, 97.5, 99.9, 104.5, 108, 109.7, 113.8, 118.5, 124.1, 130.4, 136.2, 140.9, 144.4, 148, 152.5, 157.3, 160.8, 163.2, 166.7, 172.4, 177.5, 180.7, 183.9, 189.4, 196.4, 203.5, 208.3, 218.8, 215.7, 218.3, 225.7, 229.8, 233.9, 238.3, 238.6, 240.6, 244.9, 251.9, 256.1, 260.3, 269.2]

# %%
#Citation for Linear Regression:
#Biswal, A. (2023, April 3). Sklearn linear regression (step-by-step explanation): Sklearn Tutorial. Simplilearn.com. 
#Retrieved from https://www.simplilearn.com/tutorials/scikit-learn-tutorial/sklearn-linear-regression-with-examples 
x_axis = np.array(linear_years).reshape(-1, 1)
y_axis = np.array(linear_cpi).reshape(-1, 1)
trainx, testx, trainy, testy = train_test_split(x_axis, y_axis, test_size = 0.9)
lin_reg = LinearRegression()
lin_reg.fit(trainx, trainy)
#print(lin_reg.score(X_test, y_test))
# Out:
# LinearRegression()

# %%
data_prediction = lin_reg.predict(testx)
plt.scatter(testx, testy, color ='b')
plt.plot(testx, data_prediction, color ='k')
plt.xlabel('Year')
plt.ylabel('CPI')
plt.title('Linear Test Data 1980 - 2021')
plt.show()

# %%
user_input = int(input("please input year after 2021: "))
# Out:
# please input year after 2021: 2025

# %%
if (user_input > 2021):
    y_predict = lin_reg.intercept_ + lin_reg.coef_ * user_input
    future_predict = float(y_predict)
    print("The estimated CPI for that year is: ", round(future_predict, 2))
    #print(round(future_predict, 2))
else:
    print("Please enter a year after 2021 and try again")
# Out:
# The estimated CPI for that year is:  286.39

# %%
#Average CPI Over Next 5 Years
mean_years = [user_input]
mean_cpi = [y_predict]
sum_cpi = 0
for years in mean_years:
    if years < user_input + 5:
        years = years + 1
        mean_years.append(years)
        mean_cpi.append(lin_reg.intercept_ + lin_reg.coef_ * years)
        sum_cpi = sum_cpi + (lin_reg.intercept_ + lin_reg.coef_ * years)
round_cpi = float(sum_cpi / 5)    
print('The Average (Mean) CPI Over Next 5 Years From Input Date: ', round(round_cpi, 2))

#print(round(round_cpi, 2))
# Out:
# The Average (Mean) CPI Over Next 5 Years From Input Date:  299.77

# %%
new_years = [user_input]
new_cpi = [y_predict]
for years in new_years:
    if years < user_input + 25:
        years = years + 1
        new_years.append(years)
        new_cpi.append(lin_reg.intercept_ + lin_reg.coef_ * years)

# %%
plt.scatter(new_years, new_cpi)
plt.xlabel('Year')
plt.ylabel('CPI')
plt.title("Estimated CPI For 25 Years After Input Year")
plt.show()

# %%
#historical data in a editable format to append with predictive data
future_years = [1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
future_cpi = [9.8, 10.2, 10.2, 10.6, 13.3, 15.1, 17.7, 20.6, 17.7, 16.8, 17, 17.2, 17.3, 17.8, 17.4, 17.2, 17.3, 16.9, 15.3, 13.6, 13.1, 13.4, 13.7, 13.9, 14.4, 14.1, 14.1, 14, 15.1, 16.4, 17.5, 17.7, 18.1, 19.2, 22, 24.1, 23.9, 23.7, 26.2, 26.7, 26.8, 26.9, 26.9, 27.4, 28.3, 28.9, 29.2, 29.8, 30, 30.4, 30.6, 31.1, 31.6, 32.7, 33.3, 34.9, 37, 38.8, 40.7, 41.7, 44.3, 48.6, 54.3, 56.8, 61.2, 65.2, 73.1, 83.3, 91.6, 97.5, 99.9, 104.5, 108, 109.7, 113.8, 118.5, 124.1, 130.4, 136.2, 140.9, 144.4, 148, 152.5, 157.3, 160.8, 163.2, 166.7, 172.4, 177.5, 180.7, 183.9, 189.4, 196.4, 203.5, 208.3, 218.8, 215.7, 218.3, 225.7, 229.8, 233.9, 238.3, 238.6, 240.6, 244.9, 251.9, 256.1, 260.3, 269.2]
biggest_num = 2021
while biggest_num < (user_input):
        biggest_num = biggest_num + 1
        updated_cpi = float(lin_reg.intercept_ + lin_reg.coef_ * biggest_num)
        future_years.append(biggest_num)
        future_cpi.append(round(updated_cpi, 2))

# %%
plt.plot(future_years, future_cpi)
plt.xlabel('Year')
plt.ylabel('CPI')
plt.title("Historical Data Through Input Date")
plt.show()
